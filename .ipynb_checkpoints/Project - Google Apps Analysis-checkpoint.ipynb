# %% [markdown]
# ## Introduction
#
# In this mini project, you will explore and analyze the Google Apps dataset. There is no question so you will have to be self motivated in finding out what you want to know about this data, what looks interesting to you and what results to want to communicate.
#
# We will provide some questions and examples as initial guidance. You can (and should) also discuss with the tutors and other class mates on ideas, things you want to achieve and Python techniques during class.
#
# Son Huynh
# 31.01.2020

# %% [markdown]
# Deadline: **10am 06.03** (Friday)
#
# Submit link: https://www.dropbox.com/request/ZvBWoQUCy8pwRVxQxwJx

# %%
# !pip install squarify
# Out:
# Requirement already satisfied: squarify in c:\users\mustakarhu\anaconda3\lib\site-packages (0.4.3)

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns

#extra lib for treemaps
import squarify

# %%
apps = pd.read_csv('googleplaystore.csv')

# %%
apps.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#     Reviews  Size     Installs  Type Price Content Rating  \
# 0     159.0   19M      10,000+  Free     0       Everyone
# 1     967.0   14M     500,000+  Free     0       Everyone
# 2   87510.0  8.7M   5,000,000+  Free     0       Everyone
# 3  215644.0   25M  50,000,000+  Free     0           Teen
# 4     967.0  2.8M     100,000+  Free     0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver
# 0               Art & Design   2018-01-07               1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play   2018-01-15               2.0.0  4.0.3 and up
# 2               Art & Design   2018-08-01               1.2.4  4.0.3 and up
# 3               Art & Design   2018-06-08  Varies with device    4.2 and up
# 4    Art & Design;Creativity   2018-06-20                 1.1    4.4 and up

# %%
import re
apps = pd.read_csv('googleplaystore.csv')

# drop duplicated rows
apps.drop_duplicates(inplace = True, keep='first', subset = 'App')

apps.columns = apps.columns.str.replace(' ', '')
# change price to a float data type
apps.Price = apps.Price.str.replace('$', '')
apps.Price = apps.Price.astype(float)
# change installs to an integer data type
apps.Installs = apps.Installs.str.replace(r'[,+]', '')
apps.Installs = apps.Installs.astype(int)

# change size to number value in MB
repl = lambda x: (x.group(0)[1:-1])
apps.Size = apps.Size.str.replace('Varies with device', '0')
apps.Size = apps.Size.str.replace('M','000')
apps.Size = apps.Size.str.replace(r'(\.[0-9]000)', repl)
apps.Size = apps.Size.str.replace(r'[k]', '')
apps.Size = apps.Size.str.replace(r'\.[0-9]','')
apps.Size = apps.Size.astype(int)/1000

# clean up type
apps['Type'].fillna('Free', inplace=True)

# clean up Rating, replace nan with 0
apps['Rating'].fillna(0, inplace=True)

# clean up current version, replace nan with 0
apps['CurrentVer'].fillna(0, inplace = True)

# clean up Android version, replace nan with 0
apps['AndroidVer'].fillna('0.00', inplace = True)

# add android major version x.y
apps['AndroidVerMajor'] = apps.AndroidVer.str[:3]
apps.AndroidVerMajor = apps.AndroidVerMajor.str.replace('Var', '0')
apps.AndroidVerMajor = apps.AndroidVerMajor.astype(float)

# add category as numeric labels
labels = {}
for idx, category in enumerate(apps.Category.unique().tolist()):
    labels[category] = idx
apps['CategoryLabels'] = apps.Category.map(lambda x: labels[x], na_action='ignore')

# %%
apps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9660 entries, 0 to 10840
# Data columns (total 15 columns):
# App                9660 non-null object
# Category           9659 non-null object
# Rating             9660 non-null float64
# Reviews            9660 non-null float64
# Size               9660 non-null float64
# Installs           9660 non-null int32
# Type               9660 non-null object
# Price              9660 non-null float64
# ContentRating      9660 non-null object
# Genres             9659 non-null object
# LastUpdated        9660 non-null object
# CurrentVer         9660 non-null object
# AndroidVer         9660 non-null object
# AndroidVerMajor    9660 non-null float64
# CategoryLabels     9659 non-null float64
# dtypes: float64(6), int32(1), object(8)
# memory usage: 1.1+ MB

# %% [markdown]
# ### One of the greatest qualities of a data analyst is the ability to ask questions yourself. Be curious about your data.
#
# Below is a suggested workflow and some questions to motivate you. Try to think of other questions as well.

# %% [markdown]
# 1- Data cleaning:
#     - Use string slicing and string methods to change columns like 'Size', 'Installs', 'Price', ... to numbers
#     - Remove duplicate rows
#
#
# 2- Inspect the data, calculate some statistics and write some comments on interesting observations.
#     - Which are the top 10-20 most installed (reviewed) apps? Do you see any weird app?
#     - Which are the top 10-20 most expensive apps?
#     - Which popular apps (100,000+ installs) are disliked the most?
#
# 3- Visualize and comment on some or all columns. For example:
#     - Pick a few interesting columns and make a pairplot. Do you see any interesting scatterplot?
#     - Which categories have the most apps? Which categories are most popular (by installs)?
#     - What is the range of application size (maybe using a boxplot?)
#     - Visualize the distribution of price for paid apps only
#     - Plot the Content Rating column
#
#
# 4- More possibly interesting questions to explore:
#     - Shows the relationship between price, rating and category (pick only 5 categories)
#     - Do free apps have more installs than paid apps on average?
#     - Which categories appear the most among top 100 most expensive apps?
#     - Can you show the top 100 most common words that appear in apps name?
#
# 5- Ultimately, even without predictive analytic, your report should have at least 1 actionable recommendation. You could:
#     - Pick a category/genre and answer this question: If I want to develop an app in this domain, what should I remember?
#     - Or a more general question: I want to be a mobile dev, what is a good advice for me?

# %% [markdown]
# ### Remember to comment something after you produce a statistic table or chart to summarize the results or discuss things that you found interesting.
#
# Communication is also an important skill in data analysis. Without meaningful summary and comments, people won't understand your beautiful chart.

# %% [markdown]
# <p style="color:green;">Example</p>

# %% [markdown]
# Group the data by category and explore the average rating

# %%
gb = apps.groupby('Category')

cat_mean = gb.mean()

cat_mean
# Out:
#                        Rating        Reviews       Size      Installs  \
# Category
# ART_AND_DESIGN       4.153125   22175.046875  11.984375  1.786533e+06
# AUTO_AND_VEHICLES    3.598824   13690.188235  17.679835  6.250613e+05
# BEAUTY               3.390566    7476.226415  12.233962  5.131519e+05
# BOOKS_AND_REFERENCE  3.307658   75321.234234  11.478072  7.504367e+06
# BUSINESS             2.566429   23548.202381  12.414440  1.659916e+06
# COMICS               4.032143   41822.696429  12.070589  8.032348e+05
# COMMUNICATION        3.349524  907337.676190   8.686978  3.504215e+07
# DATING               3.111111   21190.315789  14.562094  8.241293e+05
# EDUCATION            4.327731  112303.764706  14.252790  2.965983e+06
# ENTERTAINMENT        4.135294  340810.294118  14.458824  2.072216e+07
# EVENTS               3.118750    2515.906250  12.436469  2.495806e+05
# FAMILY               3.668614   78507.362445  25.614884  2.416999e+06
# FINANCE              3.602609   36701.756522  15.052377  1.319851e+06
# FOOD_AND_DRINK       3.501786   56473.464286  16.102679  1.891060e+06
# GAME                 4.039208  648903.763295  38.112148  1.447229e+07
# HEALTH_AND_FITNESS   3.594792   74171.371528  16.650597  3.972300e+06
# HOUSE_AND_HOME       3.477027   26079.013514  13.380486  1.313682e+06
# LIBRARIES_AND_DEMO   3.183333   10795.607143  10.224202  6.309037e+05
# LIFESTYLE            3.339024   32066.859079  13.436862  1.365375e+06
# MAPS_AND_NAVIGATION  3.635878  135337.007634  13.369382  3.841846e+06
# MEDICAL              3.058987    2994.863291  17.877719  9.669159e+04
# NEWS_AND_MAGAZINES   3.310236   91063.889764   9.868142  9.327629e+06
# PARENTING            3.583333   15972.183333  20.261667  5.253518e+05
# PERSONALIZATION      3.433511  142401.808511  10.478306  4.075784e+06
# PHOTOGRAPHY          3.891103  374915.551601  12.376822  1.654501e+07
# PRODUCTIVITY         3.366845  148638.098930   9.603393  1.548955e+07
# SHOPPING             3.769307  220553.118812  12.883965  6.932420e+06
# SOCIAL               3.607531  953672.807531  12.640138  2.296179e+07
# SPORTS               3.372923  108765.578462  21.097332  3.373768e+06
# TOOLS                3.507134  277335.644498   7.763306  9.675661e+06
# TRAVEL_AND_LOCAL     3.474886  122464.570776  19.120379  1.321866e+07
# VIDEO_PLAYERS        3.672393  414015.754601  12.304785  2.409143e+07
# WEATHER              3.867089  155634.987342   8.988380  4.570893e+06
#
#                         Price  AndroidVerMajor  CategoryLabels
# Category
# ART_AND_DESIGN       0.093281         3.746875             0.0
# AUTO_AND_VEHICLES    0.158471         3.768235             1.0
# BEAUTY               0.000000         3.709434             2.0
# BOOKS_AND_REFERENCE  0.539505         3.055856             3.0
# BUSINESS             0.417357         3.626190             4.0
# COMICS               0.000000         3.421429             5.0
# COMMUNICATION        0.263937         2.929206             6.0
# DATING               0.160468         3.957310             7.0
# EDUCATION            0.150924         2.974790             8.0
# ENTERTAINMENT        0.078235         2.902941             9.0
# EVENTS               1.718594         3.629687            10.0
# FAMILY               1.309967         3.597817            18.0
# FINANCE              8.408203         3.655652            11.0
# FOOD_AND_DRINK       0.075714         3.447321            12.0
# GAME                 0.296465         3.459437            17.0
# HEALTH_AND_FITNESS   0.223438         3.309722            13.0
# HOUSE_AND_HOME       0.000000         3.318919            14.0
# LIBRARIES_AND_DEMO   0.011786         2.803571            15.0
# LIFESTYLE            6.398022         3.566125            16.0
# MAPS_AND_NAVIGATION  0.205725         3.285496            32.0
# MEDICAL              2.520759         3.795696            19.0
# NEWS_AND_MAGAZINES   0.015669         3.310630            31.0
# PARENTING            0.159667         3.838333            28.0
# PERSONALIZATION      0.400213         3.503191            26.0
# PHOTOGRAPHY          0.420925         3.243772            22.0
# PRODUCTIVITY         0.670936         3.163904            27.0
# SHOPPING             0.027129         3.460396            21.0
# SOCIAL               0.066820         3.253556            20.0
# SPORTS               0.307692         3.601538            23.0
# TOOLS                0.323156         3.371584            25.0
# TRAVEL_AND_LOCAL     0.228082         3.419635            24.0
# VIDEO_PLAYERS        0.064172         3.298160            30.0
# WEATHER              0.410380         2.801266            29.0

# %%
rating = cat_mean.plot(kind='bar', y='Rating', figsize=(20,6))

#rating.set_ylim(3, 4.5)

rating.axhline(y=4, color='r')

# %% [markdown]
# We can see that Events apps are usually rated very high in the market. Other highly rated categories are Art, Books and Education.
#
# All categories except Dating apps have an average rating above 4. It could either be that people are often frustrated with dating apps, or that these apps tend to have poor design and functionality.

# %% [markdown]
# ### Additionally, you can look for well made notebooks on kaggle.com. Here is one good example on the Titanic dataset that you can draw inspiration from:
#
# https://www.kaggle.com/ash316/eda-to-prediction-dietanic

# %% [markdown]
# ### Now it's your turn to explore the data

# %% [markdown]
# There isn't too much correlation between the different metrics. Except for...
#
# **Reviews to Installs.**

# %%
sns.heatmap(apps.corr(), annot=True)

# %%
n = 20 # top n installed apps
t = 1000000 # number of installs
d = apps[(apps.Installs >= t)].sort_values(['Reviews', 'Installs'], ascending = False).head(n)
rng = len(d.Category.unique())

color = sns.cubehelix_palette(rng, start=0.0, rot=-.4)
g = sns.catplot(x="App", y="Reviews", hue='Category', data=d, kind="bar", aspect = 1.8, palette=color, dodge=False).set(title = f'Top {n} reviewed apps')
g.set_xticklabels(rotation = 90)

# %%
n = 20 # n most expensive apps.

d = apps.sort_values('Price', ascending = False).head(20)

g = sns.catplot(kind='bar', x='App', y='Price', data = d, aspect = 1.5, palette = 'Greens_d').set(title = f'{n} most expensive apps')
g.set_xticklabels(rotation = 90)

# %%
n = 20 # top 20
t = 10000000 # more than 10 million downloads

d = apps[(apps.Installs >= t)].sort_values('Rating', ascending = True)


g = sns.catplot(kind = 'bar', x='App', y='Rating', hue='Category', data=d.head(n), aspect = 2, dodge=False, palette="Greens_d").set(title=f'{n} worst rated apps with more than {t} downloads')
g.set_xticklabels(rotation = 90)

# %%
# success per category


fig, ax = plt.subplots(2,1, figsize=(12,12))

sns.violinplot('Rating','ContentRating', hue='Type', split=True, data = apps, ax=ax[0])
sns.violinplot('Size', 'ContentRating', hue='Type', split=True, data = apps, ax=ax[1])

# %%
fig, ax = plt.subplots(1,1, figsize = (12, 5))
b = apps.groupby('AndroidVerMajor').agg({'Rating': 'median'}).reset_index()

a1 = apps.AndroidVerMajor.value_counts().sort_index(ascending = True).plot(kind='bar', title ='Number of apps per android Version (Version x.y.)', ax=ax)
a2 = b.Rating.plot(kind='line', ax=ax, secondary_y = True, color='r')

# %%
"Which categories have the most apps? Which categories are most popular (by installs)?"

# Select the n most common categories and aggregate the rest of the categories in a single value
n = 10
categories = apps.Category.value_counts().head(n)
installs = apps.groupby('Category').agg({'Installs':'sum'}).sort_values(['Installs'], ascending = False).head(n)

# Tree map
cmap = plt.cm.Greens
mini=min(categories)
maxi=max(categories)
norm = matplotlib.colors.Normalize(vmin=mini, vmax=maxi)
colors = [cmap(norm(value)) for value in categories]

fig, ax = plt.subplots(2,1, figsize = (15,10))
ax[0].title.set_text(f'The {n} most popular app categories')
ax[1].title.set_text(f'The {n} most popular app categories by installs')

# plt.title(,fontsize=23,fontweight="bold")
# plt.rcParams.update({'font.size':'8', 'font.weight':'bold'})

ax1 = squarify.plot(sizes = categories.tolist(), label = categories.index, alpha = 0.8, color= colors, ax=ax[0])
ax2 = squarify.plot(sizes = installs.Installs.tolist(), label = installs.index, alpha = 0.8, ax=ax[1])

plt.axis('off')
plt.show()

# %%
"What is the range of application size (maybe using a boxplot?)"
t = 100000 # only applications with more than 100k installs
ds = apps[apps.Installs>t]

fig, ax = plt.subplots(1,2, figsize = (15,5))

ax[0].title.set_text('Range of Application size per number of installs')
ax[1].title.set_text('Range of Application size per Content Rating')

#formatting text orientation for number of installs graph
for tick in ax[0].get_xticklabels():
        tick.set_rotation(90)

ax0 = sns.boxplot(x = 'Installs', y= 'Size',hue='Type', data = ds, ax=ax[0])
ax1 = sns.boxplot(x = 'ContentRating', y= 'Size', hue='Type', data = ds, ax = ax[1])

# %%
'Visualize the distribution of price for paid apps only'
t = 100000 # only use values with more than t installs
# ds = apps[(apps.Type =='Paid') & (apps.Installs>t)].Price.value_counts()
ds = apps[['Type', 'Price','Installs','Category']]
ds = apps[(apps.Type == 'Paid')]
ds2 = ds[ds.Installs>t]

# ds.plot(kind = 'density')
# ds.sort_index(ascending = True).plot(kind = 'bar', secondary_y = True)
# ds.columns

g = sns.FacetGrid(ds, aspect = 2)
g.map(sns.distplot, 'Price')

g2 = sns.FacetGrid(ds2, aspect=2)
g2.map(sns.distplot, 'Price')

# %%
"Plot the Content Rating column"
gb = apps.groupby('ContentRating')
fig, ax = plt.subplots(1,1, figsize = (15,5))
ax.set(title='number of Apps/Installs')

ax1 = gb.App.count().plot(kind = 'line', label='Number of Apps')
plt.ylabel('Number of apps')
ax2 = gb.Installs.sum().plot(kind='bar', secondary_y = True, label='Number of Installs', color='r', ax=ax)
plt.ylabel('Number of Installs')

plt.show()

# %%
"Shows the relationship between price, rating and category (pick only 5 categories)"
# we select the n most popular categories
n=5
tmp = apps.Category.value_counts().head(n)

# filter out from the apps df that do not belong to the top 5 categories
ds = apps[apps.Category.isin(tmp.keys().tolist())]

# joint plot for each of the categories
# for cat in ds.Category.unique():
#     sns.jointplot(x='Price',y='Rating', data=ds[ds.Category==cat] , kind='reg', color='g')
    
# pair plot for all
sns.pairplot(ds[['Price', 'Rating', 'CategoryLabels']])

# %%
"Do free apps have more installs than paid apps on average?"

apps.groupby(apps.Type).Installs.describe()['mean']
# Out:
# Type
# Free    8.430545e+06
# Paid    7.587947e+04
# Name: mean, dtype: float64

# %%
"can you show the top 100 most common words that appear in apps name?"
import re
words = {}
x = apps
x.App = x.App.str.replace(r'[^a-zA-Z0-9 \n\.]','')
listofwords = x.App.map(lambda x: x.lower().split(), na_action='ignore')

for wordlist in listofwords:
    for word in wordlist:
        words[word]= 1 if (word not in words.keys()) else words[word]+1       


d = {'word':[], 'occurrences':[]}
for idx, w in enumerate(sorted(words, key=words.get, reverse=True)):
    if idx>99:
        break
    else:
        d['word'].append(w)
        d['occurrences'].append(words[w])

        
df = pd.DataFrame(data = d)

fig, ax = plt.subplots(2, 2, figsize= (25,17))
ax0=df.head(25).plot(x='word', y='occurrences', kind='bar', ax=ax[0,0], color='g')
ax1=df.loc[26:51].plot(x='word', y='occurrences', kind='bar', ax=ax[0,1], color='g')
ax2 = df.loc[51:76].plot(x='word', y='occurrences', kind='bar', ax=ax[1,0], color='g')
ax3 = df.tail(25).plot(x='word', y='occurrences', kind='bar', ax=ax[1,1], color='g')
ax[0,0].set(title='Most common words 1-25')
ax[0,1].set(title='Most common words 26-50')
ax[1,0].set(title='Most common words 51-75')
ax[1,1].set(title='Most common words 76-100')
ax1.set_ylim([0, 100])
ax2.set_ylim([0, 100])
ax3.set_ylim([0, 100])
fig.tight_layout(pad=3.0)
plt.show()

# %%
# get the n most expensive apps
n = 100
ds = apps.sort_values('Price', ascending=False).head(n)
fig, ax = plt.subplots(1,1, figsize =(10,5))
ax0 = ds.Category.value_counts().plot(kind='bar', color = 'b', ax=ax)
ax0.set(title=f'Number of apps per category on the top {n} most expensive apps')
ax0.set(ylabel = 'Count of occurrences', xlabel = 'App Category')
# Out:
# [Text(0, 0.5, 'Count of occurrences'), Text(0.5, 0, 'App Category')]

# %%
"Pick a category/genre and answer this question: If I want to develop an app in this domain, what should I remember?"

"""MEDICAL APPS"""
gb_medic = apps.groupby(apps.Category == 'MEDICAL')

print('MEDICAL apps usually receive less reviews and have less installs than other types of app.\n\
They need to be updated more frequently to more recent android versions. On top of that the pricing of MEDICAL apps is normally higher.')
fig, ax = plt.subplots(1,2, figsize=(15,4))
ax0 = gb_medic['Price'].mean().plot(kind='bar', ax=ax[0], color='b')
ax1 = gb_medic['Installs'].mean().plot(kind='bar', ax=ax[1], color='b')
a = ax0.set(ylabel='Average selling price in USD', title='Price difference - Medical Apps')
a = ax1.set(ylabel='Average Number of installs', title='Installs difference - Medical Apps')
plt.show()

gb_medic.mean()
# Out:
# MEDICAL apps usually receive less reviews and have less installs than other types of app.
# They need to be updated more frequently to more recent android versions. On top of that the pricing of MEDICAL apps is normally higher.
#             Rating        Reviews       Size      Installs     Price  \
# Category
# False     3.561522  225675.620291  17.799717  8.104128e+06  1.038579
# True      3.058987    2994.863291  17.877719  9.669159e+04  2.520759
#
#           AndroidVerMajor  CategoryLabels
# Category
# False            3.432121       17.723122
# True             3.795696       19.000000
