# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import re

# %%
#read input files
consumptions = pd.read_csv('datasets\drinks.csv')
countries = pd.read_csv('datasets\countryContinent.csv', encoding = "ISO-8859-1")


rp = {
    'Antigua and Barbuda': 'Antigua & Barbuda', 'Bolivia (Plurinational State of)': 'Bolivia', 'Bosnia and Herzegovina':'Bosnia-Herzegovina', 
        'Brunei Darussalam': 'Brunei', 'Côte d\'Ivoire': 'Cote d\'Ivoire', 'Korea (Democratic People\'s Republic of)':'North Korea', 'Congo (Democratic Republic of the)' : 'DR Congo',
      'Iran (Islamic Republic of)':'Iran', 'Lao People\'s Democratic Republic':'Laos', 'Micronesia (Federated States of)':'Micronesia', 'Korea (Republic of)':'South Korea',
      'Moldova (Republic of)':'Moldova', 'Saint Kitts and Nevis':'St. Kitts & Nevis', 'Saint Lucia':'St. Lucia', 'Saint Vincent and the Grenadines':'St. Vincent & the Grenadines',
      'Sao Tome and Principe':'Sao Tome & Principe', 'Syrian Arab Republic':'Syria', 'Macedonia (the former Yugoslav Republic of)':'Macedonia',
      'Trinidad and Tobago':'Trinidad & Tobago', 'United Kingdom of Great Britain and Northern Ireland':'United Kingdom', 'Tanzania, United Republic of':'Tanzania',
      'United States of America':'USA', 'Venezuela (Bolivarian Republic of)':'Venezuela', 'Viet Nam':'Vietnam'
     }
    
    

# for keys, values in rp.items():
#     print(countries.country[keys])


# relevant data to be merged.
cols = ['country', 'continent', 'sub_region']

# using join function to join tables based on country name
c2 = consumptions.set_index('country').join(countries[cols].set_index('country'))
c2.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-2bccea281005> in <module>
#      15
#      16
# ---> 17 print(countries.country['Viet Nam'])
#      18 # for keys, values in rp.items():
#      19 #     print(countries.country[keys])
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     866         key = com.apply_if_callable(key, self)
#     867         try:
# --> 868             result = self.index.get_value(self, key)
#     869
#     870             if not is_scalar(result):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4373         try:
#    4374             return self._engine.get_value(s, k,
# -> 4375                                           tz=getattr(series.dtype, 'tz', None))
#    4376         except KeyError as e1:
# ...

# %%
c2.sort_values(['beer_servings'], ascending = False).head()
# Out:
#                 beer_servings  spirit_servings  wine_servings  \
# country
# Namibia                   376                3              1
# Czech Republic            361              170            134
# Gabon                     347               98             59
# Germany                   346              117            175
# Lithuania                 343              244             56
#
#                 total_litres_of_pure_alcohol continent       sub_region
# country
# Namibia                                  6.8    Africa  Southern Africa
# Czech Republic                          11.8    Europe   Eastern Europe
# Gabon                                    8.9    Africa    Middle Africa
# Germany                                 11.3    Europe   Western Europe
# Lithuania                               12.9    Europe  Northern Europe

# %%
c2.sort_values(['spirit_servings'], ascending = False).head()
# Out:
#                     beer_servings  spirit_servings  wine_servings  \
# country
# Grenada                       199              438             28
# Belarus                       142              373             42
# Haiti                           1              326              1
# Russian Federation            247              326             73
# St. Lucia                     171              315             71
#
#                     total_litres_of_pure_alcohol continent      sub_region
# country
# Grenada                                     11.9  Americas       Caribbean
# Belarus                                     14.4    Europe  Eastern Europe
# Haiti                                        5.9  Americas       Caribbean
# Russian Federation                          11.5    Europe  Eastern Europe
# St. Lucia                                   10.1       NaN             NaN

# %%
c2.sort_values(['wine_servings'], ascending = False).head()
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# country
# France                 127              151            370
# Portugal               194               67            339
# Andorra                245              138            312
# Switzerland            185              100            280
# Denmark                224               81            278
#
#              total_litres_of_pure_alcohol continent       sub_region
# country
# France                               11.8    Europe   Western Europe
# Portugal                             11.0    Europe  Southern Europe
# Andorra                              12.4    Europe  Southern Europe
# Switzerland                          10.2    Europe   Western Europe
# Denmark                              10.4    Europe  Northern Europe
